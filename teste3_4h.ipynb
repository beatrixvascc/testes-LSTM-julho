# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %%
dados = np.load("/content/mimic_X_y_mask_10j_clean_bal.npz")

# Extraindo os arrays
X_bal = dados["X"]
y_bal = dados["y"]
mask_bal = dados["mask"]

print("Dados carregados da versão balanceada")
print(f"Total de amostras: {len(y_bal)}")
print(f"Com Sepse: {np.sum(y_bal == 1)}")
print(f"Sem Sepse: {np.sum(y_bal == 0)}")
# Out:
# Dados carregados da versão balanceada
# Total de amostras: 13560
# Com Sepse: 6780
# Sem Sepse: 6780

# %% [markdown]
# - taxa de aprendinzado de 0.0005
# - patience = 10
# - mais uma camada Dense com 32 neuronios para refinar o modelo
# - 50 epochs

# %%
# Divisão treino + temp (validação+teste)
X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X_bal, y_bal, mask_bal, test_size=0.30, random_state=42, stratify=y_bal
)

# Divisão temp => validação e teste (50/50% de 30%)
X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp
)

# Forma da entrada
input_shape = X_train.shape[1:]

# Definição do modelo LSTM
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(128, return_sequences=True)(x)
x = layers.LSTM(64)(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, outputs)

# Compilar o modelo
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Treinamento
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.5620 - auc: 0.5792 - loss: 0.7403 - precision: 0.5687 - recall: 0.4615 - val_accuracy: 0.6229 - val_auc: 0.6602 - val_loss: 0.6945 - val_precision: 0.6102 - val_recall: 0.6804
# Epoch 2/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.6253 - auc: 0.6633 - loss: 0.6897 - precision: 0.6164 - recall: 0.6774 - val_accuracy: 0.6214 - val_auc: 0.6711 - val_loss: 0.6822 - val_precision: 0.5915 - val_recall: 0.7847
# Epoch 3/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.6490 - auc: 0.6989 - loss: 0.6562 - precision: 0.6398 - recall: 0.6988 - val_accuracy: 0.6519 - val_auc: 0.6967 - val_loss: 0.6539 - val_precision: 0.6496 - val_recall: 0.6598
# Epoch 4/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.6471 - auc: 0.6951 - loss: 0.6511 - precision: 0.6343 - recall: 0.6869 - val_accuracy: 0.6470 - val_auc: 0.6969 - val_loss: 0.6551 - val_precision: 0.6705 - val_recall: 0.5782
# Epoch 5/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6379 - auc: 0.6978 - loss: 0.6452 - precision: 0.6297 - recall: 0.6757 - val_accuracy: 0.6445 - val_auc: 0.6993 - val_loss: 0.6433 - val_precision: 0.6237 - val_recall: 0.7286
# Epoch 6/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.6601 - auc: 0.7158 - loss: 0.6293 - precision: 0.6437 - recall: 0.6965 - val_accuracy: 0.6583 - val_auc: 0.7037 - val_loss: 0.6394 - val_precision: 0.6348 - val_recall: 0.7453
# Epoch 7/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.6678 - auc: 0.7244 - loss: 0.6223 - precision: 0.6591 - recall: 0.7051 - val_accuracy: 0.6593 - val_auc: 0.7128 - val_loss: 0.6325 - val_precision: 0.6558 - val_recall: 0.6706
# Epoch 8/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.6542 - auc: 0.7180 - loss: 0.6247 - precision: 0.6434 - recall: 0.7004 - val_accuracy: 0.6372 - val_auc: 0.6999 - val_loss: 0.6430 - val_precision: 0.6033 - val_recall: 0.8014
# Epoch 9/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.6636 - auc: 0.7279 - loss: 0.6167 - precision: 0.6509 - recall: 0.7321 - val_accuracy: 0.6647 - val_auc: 0.7134 - val_loss: 0.6256 - val_precision: 0.6612 - val_recall: 0.6755
# Epoch 10/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6526 - auc: 0.7167 - loss: 0.6214 - precision: 0.6435 - recall: 0.6855 - val_accuracy: 0.6593 - val_auc: 0.7129 - val_loss: 0.6310 - val_precision: 0.6484 - val_recall: 0.6962
# Epoch 11/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.6665 - auc: 0.7250 - loss: 0.6173 - precision: 0.6504 - recall: 0.6916 - val_accuracy: 0.6416 - val_auc: 0.7053 - val_loss: 0.6407 - val_precision: 0.6033 - val_recall: 0.8269
# Epoch 12/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6714 - auc: 0.7360 - loss: 0.6066 - precision: 0.6624 - recall: 0.7239 - val_accuracy: 0.6598 - val_auc: 0.7085 - val_loss: 0.6295 - val_precision: 0.6429 - val_recall: 0.7188
# Epoch 13/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6710 - auc: 0.7358 - loss: 0.6064 - precision: 0.6562 - recall: 0.7053 - val_accuracy: 0.6632 - val_auc: 0.7092 - val_loss: 0.6299 - val_precision: 0.6490 - val_recall: 0.7109
# Epoch 14/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.6693 - auc: 0.7355 - loss: 0.6046 - precision: 0.6633 - recall: 0.6836 - val_accuracy: 0.6642 - val_auc: 0.7162 - val_loss: 0.6244 - val_precision: 0.6708 - val_recall: 0.6450
# Epoch 15/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6702 - auc: 0.7371 - loss: 0.6040 - precision: 0.6644 - recall: 0.6904 - val_accuracy: 0.6539 - val_auc: 0.7094 - val_loss: 0.6293 - val_precision: 0.6685 - val_recall: 0.6106
# Epoch 16/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6764 - auc: 0.7438 - loss: 0.5977 - precision: 0.6672 - recall: 0.7126 - val_accuracy: 0.6593 - val_auc: 0.7099 - val_loss: 0.6277 - val_precision: 0.6478 - val_recall: 0.6981
# Epoch 17/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6785 - auc: 0.7504 - loss: 0.5919 - precision: 0.6657 - recall: 0.7053 - val_accuracy: 0.6554 - val_auc: 0.7064 - val_loss: 0.6290 - val_precision: 0.6586 - val_recall: 0.6450
# Epoch 18/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6804 - auc: 0.7460 - loss: 0.5969 - precision: 0.6778 - recall: 0.6938 - val_accuracy: 0.6613 - val_auc: 0.7088 - val_loss: 0.6354 - val_precision: 0.6691 - val_recall: 0.6382
# Epoch 19/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.6775 - auc: 0.7507 - loss: 0.5904 - precision: 0.6732 - recall: 0.6994 - val_accuracy: 0.6460 - val_auc: 0.7036 - val_loss: 0.6471 - val_precision: 0.6568 - val_recall: 0.6116
# Epoch 20/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.6799 - auc: 0.7520 - loss: 0.5887 - precision: 0.6664 - recall: 0.7027 - val_accuracy: 0.6539 - val_auc: 0.7041 - val_loss: 0.6312 - val_precision: 0.6576 - val_recall: 0.6421
# Epoch 21/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6659 - auc: 0.7398 - loss: 0.5974 - precision: 0.6592 - recall: 0.6670 - val_accuracy: 0.6598 - val_auc: 0.7126 - val_loss: 0.6350 - val_precision: 0.6444 - val_recall: 0.7129
# Epoch 22/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6784 - auc: 0.7518 - loss: 0.5883 - precision: 0.6727 - recall: 0.7038 - val_accuracy: 0.6563 - val_auc: 0.7118 - val_loss: 0.6269 - val_precision: 0.6520 - val_recall: 0.6706
# Epoch 23/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6939 - auc: 0.7586 - loss: 0.5827 - precision: 0.6888 - recall: 0.7157 - val_accuracy: 0.6559 - val_auc: 0.7107 - val_loss: 0.6316 - val_precision: 0.6706 - val_recall: 0.6126
# Epoch 24/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.6787 - auc: 0.7550 - loss: 0.5846 - precision: 0.6804 - recall: 0.6841 - val_accuracy: 0.6563 - val_auc: 0.7091 - val_loss: 0.6374 - val_precision: 0.6836 - val_recall: 0.5821

# %% [markdown]
# - acuracia de 65,4%

# %%
# Previsão das probabilidades
y_pred_prob = model.predict(X_test).flatten()

# Limiar de classificação
limiar = 0.5
y_pred = (y_pred_prob >= limiar).astype(int)

from sklearn.metrics import accuracy_score;
# Cálculo das métricas
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_val, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_val, y_pred):.4f}")
print(f"Revocação: {recall_score(y_val, y_pred):.4f}")
print(f"F1-score: {f1_score(y_val, y_pred):.4f}")

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM")
plt.show()
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Acurácia: 0.6544
# AUC: 0.5086
# Precisão: 0.5041
# Revocação: 0.4789
# F1-score: 0.4912

# %%
# Curva Precision-Recall com dados de teste
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
ap_score = average_precision_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"AP = {ap_score:.2f}", color="blue")
plt.xlabel("Recall")
plt.ylabel("Precisão")
plt.title("Curva Precision-Recall - LSTM")
plt.legend(loc="lower left")
plt.grid(True)
plt.tight_layout()
plt.show()
